# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import metrics
import env

# %%
url = f'mysql+pymysql://{env.username}:{env.password}@{env.host}/logs'
df = pd.read_sql('SELECT * FROM api_access', url)
df.head()
# Out:
#                                                entry
# 0  97.105.19.58 - - [16/Apr/2019:19:34:42 +0000] ...
# 1  97.105.19.58 - - [16/Apr/2019:19:34:42 +0000] ...
# 2  97.105.19.58 - - [16/Apr/2019:19:34:44 +0000] ...
# 3  97.105.19.58 - - [16/Apr/2019:19:34:46 +0000] ...
# 4  97.105.19.58 - - [16/Apr/2019:19:34:48 +0000] ...

# %%
df['entry'][0].split()
# Out:
# ['97.105.19.58',
#  '-',
#  '-',
#  '[16/Apr/2019:19:34:42',
#  '+0000]',
#  '"GET',
#  '/api/v1/sales?page=81',
#  'HTTP/1.1"',
#  '200',
#  '512495',
#  '"-"',
#  '"python-requests/2.21.0"']

# %%
parts = df['entry'][0].split()
output = {}

output['ip'] = parts[0]
output['timestamp'] = parts[3][1:].replace(':', ' ', 1)
pd.Series(output)
# Out:
# ip                   97.105.19.58
# timestamp    16/Apr/2019 19:34:42
# dtype: object

# %%
# function to deal with parsing one entry in our log data
def parse_log_entry(entry):
    parts = entry.split()
    output = {}
    output['ip'] = parts[0]
    output['timestamp'] = parts[3][1:].replace(':', ' ', 1)
    output['request_method'] = parts[5][1:]
    output['request_path'] = parts[6]
    output['http_version'] = parts[7][:-1]
    output['status_code'] = parts[8]
    output['size'] = int(parts[9])
    output['user_agent'] = ' '.join(parts[11:]).replace('"', '')
    return pd.Series(output)

# %%
df = df.entry.apply(parse_log_entry)
df.head()
# Out:
#              ip             timestamp request_method           request_path  \
# 0  97.105.19.58  16/Apr/2019 19:34:42            GET  /api/v1/sales?page=81
# 1  97.105.19.58  16/Apr/2019 19:34:42            GET          /api/v1/items
# 2  97.105.19.58  16/Apr/2019 19:34:44            GET  /api/v1/sales?page=82
# 3  97.105.19.58  16/Apr/2019 19:34:46            GET  /api/v1/sales?page=83
# 4  97.105.19.58  16/Apr/2019 19:34:48            GET  /api/v1/sales?page=84
#
#   http_version status_code    size              user_agent
# 0     HTTP/1.1         200  512495  python-requests/2.21.0
# 1     HTTP/1.1         200    3561  python-requests/2.21.0
# 2     HTTP/1.1         200  510103  python-requests/2.21.0
# 3     HTTP/1.1         200  510003  python-requests/2.21.0
# 4     HTTP/1.1         200  511963  python-requests/2.21.0

# %%
df['size_mb'] = df['size'] / 1024 / 1024
df.timestamp = pd.to_datetime(df.timestamp)
df = df.set_index('timestamp')
df.head()
# Out:
#                                ip request_method           request_path  \
# timestamp
# 2019-04-16 19:34:42  97.105.19.58            GET  /api/v1/sales?page=81
# 2019-04-16 19:34:42  97.105.19.58            GET          /api/v1/items
# 2019-04-16 19:34:44  97.105.19.58            GET  /api/v1/sales?page=82
# 2019-04-16 19:34:46  97.105.19.58            GET  /api/v1/sales?page=83
# 2019-04-16 19:34:48  97.105.19.58            GET  /api/v1/sales?page=84
#
#                     http_version status_code    size              user_agent  \
# timestamp
# 2019-04-16 19:34:42     HTTP/1.1         200  512495  python-requests/2.21.0
# 2019-04-16 19:34:42     HTTP/1.1         200    3561  python-requests/2.21.0
# 2019-04-16 19:34:44     HTTP/1.1         200  510103  python-requests/2.21.0
# 2019-04-16 19:34:46     HTTP/1.1         200  510003  python-requests/2.21.0
# 2019-04-16 19:34:48     HTTP/1.1         200  511963  python-requests/2.21.0
#
#                       size_mb
# timestamp
# 2019-04-16 19:34:42  0.488753
# 2019-04-16 19:34:42  0.003396
# 2019-04-16 19:34:44  0.486472
# 2019-04-16 19:34:46  0.486377
# 2019-04-16 19:34:48  0.488246

# %% [markdown]
# ### In this exercises, I will explore request_path and user_agent

# %% [markdown]
# #### * request_path

# %%
df.request_path.value_counts()
# Out:
# /api/v1/sales?page=2                 709
# /api/v1/items                        464
# /api/v1/items?page=2                 291
# /api/v1/items?page=3                 219
# /api/v1/stores                       162
#                                     ...
# /api/v1/items?page=0                   1
# /api/v1/stores?page=999                1
# /api/v1/stores?page=2                  1
# /api/v1/stores?page=666                1
# /api/v1/items/api/v1/items?page=3      1
# Name: request_path, Length: 218, dtype: int64

# %%
path_df = pd.DataFrame(df.request_path.value_counts(dropna=False)).reset_index().\
                rename(columns={'index': 'path', 'request_path': 'count'})
path_df.head()
# Out:
#                    path  count
# 0  /api/v1/sales?page=2    709
# 1         /api/v1/items    464
# 2  /api/v1/items?page=2    291
# 3  /api/v1/items?page=3    219
# 4        /api/v1/stores    162

# %%
path_df2 = pd.DataFrame((df.request_path.value_counts(dropna=False))/df.request_path.count()).reset_index().\
                rename(columns={'index': 'path', 'request_path': 'proba'})
path_df2.head()
# Out:
#                    path     proba
# 0  /api/v1/sales?page=2  0.050737
# 1         /api/v1/items  0.033205
# 2  /api/v1/items?page=2  0.020824
# 3  /api/v1/items?page=3  0.015672
# 4        /api/v1/stores  0.011593

# %%
path_df = path_df.merge(path_df2, on='path')
path_df.head()
# Out:
#                    path  count     proba
# 0  /api/v1/sales?page=2    709  0.050737
# 1         /api/v1/items    464  0.033205
# 2  /api/v1/items?page=2    291  0.020824
# 3  /api/v1/items?page=3    219  0.015672
# 4        /api/v1/stores    162  0.011593

# %%
path_df
# Out:
#                                   path  count     proba
# 0                 /api/v1/sales?page=2    709  0.050737
# 1                        /api/v1/items    464  0.033205
# 2                 /api/v1/items?page=2    291  0.020824
# 3                 /api/v1/items?page=3    219  0.015672
# 4                       /api/v1/stores    162  0.011593
# ..                                 ...    ...       ...
# 213               /api/v1/items?page=0      1  0.000072
# 214            /api/v1/stores?page=999      1  0.000072
# 215              /api/v1/stores?page=2      1  0.000072
# 216            /api/v1/stores?page=666      1  0.000072
# 217  /api/v1/items/api/v1/items?page=3      1  0.000072
#
# [218 rows x 3 columns]

# %%
# prob(A|B) = prob(A & B)/prob(B)
# A = path, B = ip

# %%
path_pab = df.groupby(['ip','request_path']).size()/len(df)
path_pab
# Out:
# ip              request_path
# 173.173.113.51  /                          0.000072
#                 /api/v1/items              0.004580
#                 /api/v1/items?page=2       0.004437
#                 /api/v1/items?page=3       0.004437
#                 /api/v1/sales              0.000572
#                                              ...
# 97.105.19.58    /api/v1/stores?page=666    0.000072
#                 /api/v1/stores?page=999    0.000072
#                 /api/v1items               0.000072
#                 /documentation             0.006655
#                 /favicon.ico               0.001002
# Length: 816, dtype: float64

# %%
ip_pb = df.groupby('ip').size()/len(df)
ip_pb
# Out:
# ip
# 173.173.113.51    0.075784
# 24.26.242.9       0.001503
# 3.88.129.158      0.000072
# 3.92.201.136      0.000072
# 34.207.64.242     0.000072
# 34.229.70.250     0.000072
# 35.174.209.2      0.000072
# 35.175.171.137    0.000143
# 45.23.250.16      0.000072
# 52.87.230.102     0.000143
# 52.90.165.200     0.000072
# 52.91.30.150      0.000072
# 54.145.52.184     0.000072
# 54.172.14.223     0.000072
# 68.201.219.223    0.001503
# 70.121.214.34     0.000143
# 72.181.105.81     0.017604
# 72.181.113.170    0.043867
# 97.105.19.58      0.858595
# dtype: float64

# %%
path_pab/ip_pb
# Out:
# ip              request_path
# 173.173.113.51  /                          0.000944
#                 /api/v1/items              0.060434
#                 /api/v1/items?page=2       0.058546
#                 /api/v1/items?page=3       0.058546
#                 /api/v1/sales              0.007554
#                                              ...
# 97.105.19.58    /api/v1/stores?page=666    0.000083
#                 /api/v1/stores?page=999    0.000083
#                 /api/v1items               0.000083
#                 /documentation             0.007751
#                 /favicon.ico               0.001167
# Length: 816, dtype: float64

# %%
path_given_ip = (df.groupby('ip').request_path.value_counts(normalize=True)
                 .rename('proba_path_given_ip').reset_index())
path_given_ip.head(20)
# Out:
#                 ip           request_path  proba_path_given_ip
# 0   173.173.113.51          /api/v1/items             0.060434
# 1   173.173.113.51   /api/v1/items?page=2             0.058546
# 2   173.173.113.51   /api/v1/items?page=3             0.058546
# 3   173.173.113.51         /api/v1/stores             0.050992
# 4   173.173.113.51          /api/v1/sales             0.007554
# 5   173.173.113.51  /api/v1/sales?page=10             0.004721
# 6   173.173.113.51  /api/v1/sales?page=11             0.004721
# 7   173.173.113.51  /api/v1/sales?page=12             0.004721
# 8   173.173.113.51  /api/v1/sales?page=13             0.004721
# 9   173.173.113.51  /api/v1/sales?page=14             0.004721
# 10  173.173.113.51  /api/v1/sales?page=15             0.004721
# 11  173.173.113.51  /api/v1/sales?page=16             0.004721
# 12  173.173.113.51  /api/v1/sales?page=17             0.004721
# 13  173.173.113.51  /api/v1/sales?page=18             0.004721
# 14  173.173.113.51  /api/v1/sales?page=19             0.004721
# 15  173.173.113.51   /api/v1/sales?page=2             0.004721
# 16  173.173.113.51  /api/v1/sales?page=20             0.004721
# 17  173.173.113.51  /api/v1/sales?page=21             0.004721
# 18  173.173.113.51  /api/v1/sales?page=22             0.004721
# 19  173.173.113.51  /api/v1/sales?page=23             0.004721

# %%
path_given_ip[path_given_ip.proba_path_given_ip > 0.1]
# Out:
#                  ip           request_path  proba_path_given_ip
# 189     24.26.242.9   /api/v1/items?page=1             0.333333
# 190     24.26.242.9   /api/v1/sales?page=1             0.333333
# 191     24.26.242.9  /api/v1/stores?page=1             0.333333
# 192    3.88.129.158          /api/v1/items             1.000000
# 193    3.92.201.136                      /             1.000000
# 194   34.207.64.242           /favicon.ico             1.000000
# 195   34.229.70.250           /favicon.ico             1.000000
# 196    35.174.209.2           /favicon.ico             1.000000
# 197  35.175.171.137                      /             0.500000
# 198  35.175.171.137          /api/v1/items             0.500000
# 199    45.23.250.16         /api/v1/stores             1.000000
# 200   52.87.230.102          /api/v1/sales             0.500000
# 201   52.87.230.102           /favicon.ico             0.500000
# 202   52.90.165.200           /favicon.ico             1.000000
# 203    52.91.30.150                      /             1.000000
# 204   54.145.52.184           /favicon.ico             1.000000
# 205   54.172.14.223               /api/v1/             1.000000
# 206  68.201.219.223          /api/v1/items             0.285714
# 207  68.201.219.223   /api/v1/items?page=1             0.190476
# 208  68.201.219.223                      /             0.142857
# 209  68.201.219.223   /api/v1/items?page=2             0.142857
# 210  68.201.219.223         /documentation             0.142857
# 213   70.121.214.34                      /             0.500000
# 214   70.121.214.34           /favicon.ico             0.500000

# %%
df = df.reset_index().merge(path_given_ip, on=['ip', 'request_path'], how='left').fillna(value=0).set_index('timestamp')

# %%
df.head()
# Out:
#                                ip request_method           request_path  \
# timestamp
# 2019-04-16 19:34:42  97.105.19.58            GET  /api/v1/sales?page=81
# 2019-04-16 19:34:42  97.105.19.58            GET          /api/v1/items
# 2019-04-16 19:34:44  97.105.19.58            GET  /api/v1/sales?page=82
# 2019-04-16 19:34:46  97.105.19.58            GET  /api/v1/sales?page=83
# 2019-04-16 19:34:48  97.105.19.58            GET  /api/v1/sales?page=84
#
#                     http_version status_code    size              user_agent  \
# timestamp
# 2019-04-16 19:34:42     HTTP/1.1         200  512495  python-requests/2.21.0
# 2019-04-16 19:34:42     HTTP/1.1         200    3561  python-requests/2.21.0
# 2019-04-16 19:34:44     HTTP/1.1         200  510103  python-requests/2.21.0
# 2019-04-16 19:34:46     HTTP/1.1         200  510003  python-requests/2.21.0
# 2019-04-16 19:34:48     HTTP/1.1         200  511963  python-requests/2.21.0
#
#                       size_mb  proba_path_given_ip
# timestamp
# 2019-04-16 19:34:42  0.488753             0.004417
# 2019-04-16 19:34:42  0.003396             0.028505
# 2019-04-16 19:34:44  0.486472             0.004417
# 2019-04-16 19:34:46  0.486377             0.004417
# 2019-04-16 19:34:48  0.488246             0.004417

# %%
df[df.proba_path_given_ip == 1]
# Out:
#                                 ip request_method    request_path  \
# timestamp
# 2019-04-16 19:39:14   3.92.201.136            GET               /
# 2019-04-16 19:39:15  52.90.165.200            GET    /favicon.ico
# 2019-04-16 19:40:32   3.88.129.158            GET   /api/v1/items
# 2019-04-16 19:40:33  34.207.64.242            GET    /favicon.ico
# 2019-04-16 19:40:36  54.172.14.223            GET        /api/v1/
# 2019-04-16 19:40:37  34.229.70.250            GET    /favicon.ico
# 2019-04-16 21:22:22  54.145.52.184            GET    /favicon.ico
# 2019-04-16 21:38:57   35.174.209.2            GET    /favicon.ico
# 2019-04-17 02:14:27   52.91.30.150            GET               /
# 2019-04-17 10:25:50   45.23.250.16            GET  /api/v1/stores
#
#                     http_version status_code  size  \
# timestamp
# 2019-04-16 19:39:14     HTTP/1.1         200    42
# 2019-04-16 19:39:15     HTTP/1.1         200   162
# 2019-04-16 19:40:32     HTTP/1.1         200  3561
# 2019-04-16 19:40:33     HTTP/1.1         200   162
# 2019-04-16 19:40:36     HTTP/1.1         200   162
# 2019-04-16 19:40:37     HTTP/1.1         200   162
# 2019-04-16 21:22:22     HTTP/1.1         200   162
# 2019-04-16 21:38:57     HTTP/1.1         200   162
# 2019-04-17 02:14:27     HTTP/1.1         200    42
# 2019-04-17 10:25:50     HTTP/1.1         200  1328
#
#                                                             user_agent  \
# timestamp
# 2019-04-16 19:39:14  Slackbot-LinkExpanding 1.0 (+https://api.slack...
# 2019-04-16 19:39:15       Slackbot 1.0 (+https://api.slack.com/robots)
# 2019-04-16 19:40:32  Slackbot-LinkExpanding 1.0 (+https://api.slack...
# 2019-04-16 19:40:33       Slackbot 1.0 (+https://api.slack.com/robots)
# 2019-04-16 19:40:36  Slackbot-LinkExpanding 1.0 (+https://api.slack...
# 2019-04-16 19:40:37       Slackbot 1.0 (+https://api.slack.com/robots)
# 2019-04-16 21:22:22       Slackbot 1.0 (+https://api.slack.com/robots)
# 2019-04-16 21:38:57       Slackbot 1.0 (+https://api.slack.com/robots)
# 2019-04-17 02:14:27  Slackbot-LinkExpanding 1.0 (+https://api.slack...
# 2019-04-17 10:25:50                             python-requests/2.21.0
#
#                       size_mb  proba_path_given_ip
# timestamp
# 2019-04-16 19:39:14  0.000040                  1.0
# 2019-04-16 19:39:15  0.000154                  1.0
# 2019-04-16 19:40:32  0.003396                  1.0
# 2019-04-16 19:40:33  0.000154                  1.0
# 2019-04-16 19:40:36  0.000154                  1.0
# 2019-04-16 19:40:37  0.000154                  1.0
# 2019-04-16 21:22:22  0.000154                  1.0
# 2019-04-16 21:38:57  0.000154                  1.0
# 2019-04-17 02:14:27  0.000040                  1.0
# 2019-04-17 10:25:50  0.001266                  1.0

# %%
df[df.request_path == '/favicon.ico']
# Out:
#                                  ip request_method  request_path http_version  \
# timestamp
# 2019-04-16 19:38:16    97.105.19.58            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 19:39:15   52.90.165.200            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 19:40:33   34.207.64.242            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 19:40:37   34.229.70.250            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 19:44:04    97.105.19.58            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 19:44:16    97.105.19.58            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 19:44:24    97.105.19.58            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 19:44:28    97.105.19.58            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 19:44:38    97.105.19.58            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 19:45:20    97.105.19.58            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 19:49:43    97.105.19.58            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 19:49:53    97.105.19.58            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 19:49:58    97.105.19.58            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 19:59:47    97.105.19.58            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 20:01:03    97.105.19.58            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 20:31:10    97.105.19.58            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 21:22:22   54.145.52.184            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 21:38:57    35.174.209.2            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 21:49:22    97.105.19.58            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 22:01:52   72.181.105.81            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 22:01:53   72.181.105.81            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 22:02:42   72.181.105.81            GET  /favicon.ico     HTTP/1.1
# 2019-04-16 23:44:35   72.181.105.81            GET  /favicon.ico     HTTP/1.1
# 2019-04-17 01:25:07   70.121.214.34            GET  /favicon.ico     HTTP/1.1
# 2019-04-17 02:14:28   52.87.230.102            GET  /favicon.ico     HTTP/1.1
# 2019-04-17 02:18:07  72.181.113.170            GET  /favicon.ico     HTTP/1.1
#
#                     status_code  size  \
# timestamp
# 2019-04-16 19:38:16         200   162
# 2019-04-16 19:39:15         200   162
# 2019-04-16 19:40:33         200   162
# 2019-04-16 19:40:37         200   162
# 2019-04-16 19:44:04         200   162
# 2019-04-16 19:44:16         200   162
# 2019-04-16 19:44:24         200   162
# 2019-04-16 19:44:28         200   162
# 2019-04-16 19:44:38         200   162
# 2019-04-16 19:45:20         200   162
# 2019-04-16 19:49:43         200   162
# 2019-04-16 19:49:53         200   162
# 2019-04-16 19:49:58         200   162
# 2019-04-16 19:59:47         200   162
# 2019-04-16 20:01:03         200   162
# 2019-04-16 20:31:10         200   162
# 2019-04-16 21:22:22         200   162
# 2019-04-16 21:38:57         200   162
# 2019-04-16 21:49:22         200   162
# 2019-04-16 22:01:52         200   162
# 2019-04-16 22:01:53         200   162
# 2019-04-16 22:02:42         200   162
# 2019-04-16 23:44:35         200   162
# 2019-04-17 01:25:07         200   162
# 2019-04-17 02:14:28         200   162
# 2019-04-17 02:18:07         200   162
#
#                                                             user_agent  \
# timestamp
# 2019-04-16 19:38:16  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:39:15       Slackbot 1.0 (+https://api.slack.com/robots)
# 2019-04-16 19:40:33       Slackbot 1.0 (+https://api.slack.com/robots)
# 2019-04-16 19:40:37       Slackbot 1.0 (+https://api.slack.com/robots)
# 2019-04-16 19:44:04  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:44:16  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:44:24  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:44:28  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:44:38  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:45:20  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:49:43  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:49:53  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:49:58  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:59:47  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 20:01:03  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 20:31:10  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 21:22:22       Slackbot 1.0 (+https://api.slack.com/robots)
# 2019-04-16 21:38:57       Slackbot 1.0 (+https://api.slack.com/robots)
# 2019-04-16 21:49:22  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3...
# 2019-04-16 22:01:52  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 22:01:53  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 22:02:42  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 23:44:35  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-17 01:25:07  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3...
# 2019-04-17 02:14:28       Slackbot 1.0 (+https://api.slack.com/robots)
# 2019-04-17 02:18:07  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3...
#
#                       size_mb  proba_path_given_ip
# timestamp
# 2019-04-16 19:38:16  0.000154             0.001167
# 2019-04-16 19:39:15  0.000154             1.000000
# 2019-04-16 19:40:33  0.000154             1.000000
# 2019-04-16 19:40:37  0.000154             1.000000
# 2019-04-16 19:44:04  0.000154             0.001167
# 2019-04-16 19:44:16  0.000154             0.001167
# 2019-04-16 19:44:24  0.000154             0.001167
# 2019-04-16 19:44:28  0.000154             0.001167
# 2019-04-16 19:44:38  0.000154             0.001167
# 2019-04-16 19:45:20  0.000154             0.001167
# 2019-04-16 19:49:43  0.000154             0.001167
# 2019-04-16 19:49:53  0.000154             0.001167
# 2019-04-16 19:49:58  0.000154             0.001167
# 2019-04-16 19:59:47  0.000154             0.001167
# 2019-04-16 20:01:03  0.000154             0.001167
# 2019-04-16 20:31:10  0.000154             0.001167
# 2019-04-16 21:22:22  0.000154             1.000000
# 2019-04-16 21:38:57  0.000154             1.000000
# 2019-04-16 21:49:22  0.000154             0.001167
# 2019-04-16 22:01:52  0.000154             0.016260
# 2019-04-16 22:01:53  0.000154             0.016260
# 2019-04-16 22:02:42  0.000154             0.016260
# 2019-04-16 23:44:35  0.000154             0.016260
# 2019-04-17 01:25:07  0.000154             0.500000
# 2019-04-17 02:14:28  0.000154             0.500000
# 2019-04-17 02:18:07  0.000154             0.001631

# %% [markdown]
# #### * user_agent

# %%
agent_df = pd.DataFrame(df.user_agent.value_counts(dropna=False)).reset_index().\
                rename(columns={'index': 'agent', 'user_agent': 'count'})
agent_df.head()
# Out:
#                                                agent  count
# 0                             python-requests/2.21.0  12001
# 1                             python-requests/2.20.1   1911
# 2  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...     34
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...      8
# 4  Slackbot-LinkExpanding 1.0 (+https://api.slack...      7

# %%
agent_df2 = pd.DataFrame((df.user_agent.value_counts(dropna=False))/df.user_agent.count()).reset_index().\
                rename(columns={'index': 'agent', 'user_agent': 'proba'})
agent_df2.head()
# Out:
#                                                agent     proba
# 0                             python-requests/2.21.0  0.858809
# 1                             python-requests/2.20.1  0.136754
# 2  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...  0.002433
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...  0.000572
# 4  Slackbot-LinkExpanding 1.0 (+https://api.slack...  0.000501

# %%
agent_df = agent_df.merge(agent_df2, on='agent')
agent_df.head()
# Out:
#                                                agent  count     proba
# 0                             python-requests/2.21.0  12001  0.858809
# 1                             python-requests/2.20.1   1911  0.136754
# 2  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...     34  0.002433
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...      8  0.000572
# 4  Slackbot-LinkExpanding 1.0 (+https://api.slack...      7  0.000501

# %%
# prob(A|B) = prob(A & B)/prob(B)
# A = agent, B = ip

# %%
pab_agent = df.groupby(['ip', 'user_agent']).size()/len(df)
pab_agent
# Out:
# ip              user_agent
# 173.173.113.51  python-requests/2.21.0                                                                                                       0.075784
# 24.26.242.9     python-requests/2.21.0                                                                                                       0.001503
# 3.88.129.158    Slackbot-LinkExpanding 1.0 (+https://api.slack.com/robots)                                                                   0.000072
# 3.92.201.136    Slackbot-LinkExpanding 1.0 (+https://api.slack.com/robots)                                                                   0.000072
# 34.207.64.242   Slackbot 1.0 (+https://api.slack.com/robots)                                                                                 0.000072
# 34.229.70.250   Slackbot 1.0 (+https://api.slack.com/robots)                                                                                 0.000072
# 35.174.209.2    Slackbot 1.0 (+https://api.slack.com/robots)                                                                                 0.000072
# 35.175.171.137  Slackbot-LinkExpanding 1.0 (+https://api.slack.com/robots)                                                                   0.000143
# 45.23.250.16    python-requests/2.21.0                                                                                                       0.000072
# 52.87.230.102   Slackbot 1.0 (+https://api.slack.com/robots)                                                                                 0.000072
#                 Slackbot-LinkExpanding 1.0 (+https://api.slack.com/robots)                                                                   0.000072
# 52.90.165.200   Slackbot 1.0 (+https://api.slack.com/robots)                                                                                 0.000072
# 52.91.30.150    Slackbot-LinkExpanding 1.0 (+https://api.slack.com/robots)                                                                   0.000072
# 54.145.52.184   Slackbot 1.0 (+https://api.slack.com/robots)                                                                                 0.000072
# 54.172.14.223   Slackbot-LinkExpanding 1.0 (+https://api.slack.com/robots)                                                                   0.000072
# 68.201.219.223  python-requests/2.21.0                                                                                                       0.001503
# 70.121.214.34   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36    0.000143
# 72.181.105.81   Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0                                           0.000572
#                 Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36    0.000572
#                 python-requests/2.21.0                                                                                                       0.016459
# 72.181.113.170  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36    0.000143
#                 python-requests/2.21.0                                                                                                       0.043724
# 97.105.19.58    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36    0.000143
#                 Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36    0.001861
#                 Python-urllib/3.7                                                                                                            0.000072
#                 python-requests/2.20.1                                                                                                       0.136754
#                 python-requests/2.21.0                                                                                                       0.719765
# dtype: float64

# %%
pab_agent/ip_pb
# Out:
# ip              user_agent
# 173.173.113.51  python-requests/2.21.0                                                                                                       1.000000
# 24.26.242.9     python-requests/2.21.0                                                                                                       1.000000
# 3.88.129.158    Slackbot-LinkExpanding 1.0 (+https://api.slack.com/robots)                                                                   1.000000
# 3.92.201.136    Slackbot-LinkExpanding 1.0 (+https://api.slack.com/robots)                                                                   1.000000
# 34.207.64.242   Slackbot 1.0 (+https://api.slack.com/robots)                                                                                 1.000000
# 34.229.70.250   Slackbot 1.0 (+https://api.slack.com/robots)                                                                                 1.000000
# 35.174.209.2    Slackbot 1.0 (+https://api.slack.com/robots)                                                                                 1.000000
# 35.175.171.137  Slackbot-LinkExpanding 1.0 (+https://api.slack.com/robots)                                                                   1.000000
# 45.23.250.16    python-requests/2.21.0                                                                                                       1.000000
# 52.87.230.102   Slackbot 1.0 (+https://api.slack.com/robots)                                                                                 0.500000
#                 Slackbot-LinkExpanding 1.0 (+https://api.slack.com/robots)                                                                   0.500000
# 52.90.165.200   Slackbot 1.0 (+https://api.slack.com/robots)                                                                                 1.000000
# 52.91.30.150    Slackbot-LinkExpanding 1.0 (+https://api.slack.com/robots)                                                                   1.000000
# 54.145.52.184   Slackbot 1.0 (+https://api.slack.com/robots)                                                                                 1.000000
# 54.172.14.223   Slackbot-LinkExpanding 1.0 (+https://api.slack.com/robots)                                                                   1.000000
# 68.201.219.223  python-requests/2.21.0                                                                                                       1.000000
# 70.121.214.34   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36    1.000000
# 72.181.105.81   Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0                                           0.032520
#                 Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36    0.032520
#                 python-requests/2.21.0                                                                                                       0.934959
# 72.181.113.170  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36    0.003263
#                 python-requests/2.21.0                                                                                                       0.996737
# 97.105.19.58    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36    0.000167
#                 Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36    0.002167
#                 Python-urllib/3.7                                                                                                            0.000083
#                 python-requests/2.20.1                                                                                                       0.159277
#                 python-requests/2.21.0                                                                                                       0.838306
# dtype: float64

# %%
agent_given_ip = (df.groupby('ip').user_agent.value_counts(normalize=True)
                 .rename('proba_agent_given_ip').reset_index())
agent_given_ip.head(20)
# Out:
#                 ip                                         user_agent  \
# 0   173.173.113.51                             python-requests/2.21.0
# 1      24.26.242.9                             python-requests/2.21.0
# 2     3.88.129.158  Slackbot-LinkExpanding 1.0 (+https://api.slack...
# 3     3.92.201.136  Slackbot-LinkExpanding 1.0 (+https://api.slack...
# 4    34.207.64.242       Slackbot 1.0 (+https://api.slack.com/robots)
# 5    34.229.70.250       Slackbot 1.0 (+https://api.slack.com/robots)
# 6     35.174.209.2       Slackbot 1.0 (+https://api.slack.com/robots)
# 7   35.175.171.137  Slackbot-LinkExpanding 1.0 (+https://api.slack...
# 8     45.23.250.16                             python-requests/2.21.0
# 9    52.87.230.102       Slackbot 1.0 (+https://api.slack.com/robots)
# 10   52.87.230.102  Slackbot-LinkExpanding 1.0 (+https://api.slack...
# 11   52.90.165.200       Slackbot 1.0 (+https://api.slack.com/robots)
# 12    52.91.30.150  Slackbot-LinkExpanding 1.0 (+https://api.slack...
# 13   54.145.52.184       Slackbot 1.0 (+https://api.slack.com/robots)
# 14   54.172.14.223  Slackbot-LinkExpanding 1.0 (+https://api.slack...
# 15  68.201.219.223                             python-requests/2.21.0
# 16   70.121.214.34  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3...
# 17   72.181.105.81                             python-requests/2.21.0
# 18   72.181.105.81  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 19   72.181.105.81  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
#
#     proba_agent_given_ip
# 0               1.000000
# 1               1.000000
# 2               1.000000
# 3               1.000000
# 4               1.000000
# 5               1.000000
# 6               1.000000
# 7               1.000000
# 8               1.000000
# 9               0.500000
# 10              0.500000
# 11              1.000000
# 12              1.000000
# 13              1.000000
# 14              1.000000
# 15              1.000000
# 16              1.000000
# 17              0.934959
# 18              0.032520
# 19              0.032520

# %%
df = df.reset_index().merge(agent_given_ip, on=['ip', 'user_agent'], how='left').fillna(value=0).set_index('timestamp')
df.head()
# Out:
#                                ip request_method           request_path  \
# timestamp
# 2019-04-16 19:34:42  97.105.19.58            GET  /api/v1/sales?page=81
# 2019-04-16 19:34:42  97.105.19.58            GET          /api/v1/items
# 2019-04-16 19:34:44  97.105.19.58            GET  /api/v1/sales?page=82
# 2019-04-16 19:34:46  97.105.19.58            GET  /api/v1/sales?page=83
# 2019-04-16 19:34:48  97.105.19.58            GET  /api/v1/sales?page=84
#
#                     http_version status_code    size              user_agent  \
# timestamp
# 2019-04-16 19:34:42     HTTP/1.1         200  512495  python-requests/2.21.0
# 2019-04-16 19:34:42     HTTP/1.1         200    3561  python-requests/2.21.0
# 2019-04-16 19:34:44     HTTP/1.1         200  510103  python-requests/2.21.0
# 2019-04-16 19:34:46     HTTP/1.1         200  510003  python-requests/2.21.0
# 2019-04-16 19:34:48     HTTP/1.1         200  511963  python-requests/2.21.0
#
#                       size_mb  proba_path_given_ip  proba_agent_given_ip
# timestamp
# 2019-04-16 19:34:42  0.488753             0.004417              0.838306
# 2019-04-16 19:34:42  0.003396             0.028505              0.838306
# 2019-04-16 19:34:44  0.486472             0.004417              0.838306
# 2019-04-16 19:34:46  0.486377             0.004417              0.838306
# 2019-04-16 19:34:48  0.488246             0.004417              0.838306

# %%
df[df.proba_agent_given_ip < 0.05]
# Out:
#                                  ip request_method  \
# timestamp
# 2019-04-16 19:38:16    97.105.19.58            GET
# 2019-04-16 19:38:16    97.105.19.58            GET
# 2019-04-16 19:44:04    97.105.19.58            GET
# 2019-04-16 19:44:04    97.105.19.58            GET
# 2019-04-16 19:44:16    97.105.19.58            GET
# 2019-04-16 19:44:16    97.105.19.58            GET
# 2019-04-16 19:44:24    97.105.19.58            GET
# 2019-04-16 19:44:24    97.105.19.58            GET
# 2019-04-16 19:44:28    97.105.19.58            GET
# 2019-04-16 19:44:28    97.105.19.58            GET
# 2019-04-16 19:44:38    97.105.19.58            GET
# 2019-04-16 19:44:38    97.105.19.58            GET
# 2019-04-16 19:45:20    97.105.19.58            GET
# 2019-04-16 19:45:20    97.105.19.58            GET
# 2019-04-16 19:49:41    97.105.19.58            GET
# 2019-04-16 19:49:43    97.105.19.58            GET
# 2019-04-16 19:49:51    97.105.19.58            GET
# 2019-04-16 19:49:53    97.105.19.58            GET
# 2019-04-16 19:49:58    97.105.19.58            GET
# 2019-04-16 19:49:58    97.105.19.58            GET
# 2019-04-16 19:59:46    97.105.19.58            GET
# 2019-04-16 19:59:47    97.105.19.58            GET
# 2019-04-16 20:01:02    97.105.19.58            GET
# 2019-04-16 20:01:03    97.105.19.58            GET
# 2019-04-16 20:31:09    97.105.19.58            GET
# 2019-04-16 20:31:10    97.105.19.58            GET
# 2019-04-16 20:57:38    97.105.19.58            GET
# 2019-04-16 21:49:21    97.105.19.58            GET
# 2019-04-16 21:49:22    97.105.19.58            GET
# 2019-04-16 22:01:52   72.181.105.81            GET
# 2019-04-16 22:01:52   72.181.105.81            GET
# 2019-04-16 22:01:53   72.181.105.81            GET
# 2019-04-16 22:01:53   72.181.105.81            GET
# 2019-04-16 22:02:42   72.181.105.81            GET
# 2019-04-16 22:02:42   72.181.105.81            GET
# 2019-04-16 23:44:34   72.181.105.81            GET
# 2019-04-16 23:44:35   72.181.105.81            GET
# 2019-04-17 01:25:07   72.181.105.81            GET
# 2019-04-17 01:25:21   72.181.105.81            GET
# 2019-04-17 01:33:06   72.181.105.81            GET
# 2019-04-17 01:33:19   72.181.105.81            GET
# 2019-04-17 01:33:32   72.181.105.81            GET
# 2019-04-17 01:56:33   72.181.105.81            GET
# 2019-04-17 01:56:57   72.181.105.81            GET
# 2019-04-17 02:07:44   72.181.105.81            GET
# 2019-04-17 02:18:07  72.181.113.170            GET
# 2019-04-17 02:18:07  72.181.113.170            GET
#
#                                         request_path http_version status_code  \
# timestamp
# 2019-04-16 19:38:16                  /api/V1/HiZach!     HTTP/1.1         200
# 2019-04-16 19:38:16                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 19:44:04            /api/v1/stores?page=0     HTTP/1.1         200
# 2019-04-16 19:44:04                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 19:44:16            /api/v1/stores?page=1     HTTP/1.1         200
# 2019-04-16 19:44:16                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 19:44:24            /api/v1/stores?page=1     HTTP/1.1         200
# 2019-04-16 19:44:24                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 19:44:28            /api/v1/stores?page=2     HTTP/1.1         200
# 2019-04-16 19:44:28                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 19:44:38          /api/v1/stores?page=999     HTTP/1.1         200
# 2019-04-16 19:44:38                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 19:45:20             /api/v1/items?page=0     HTTP/1.1         200
# 2019-04-16 19:45:20                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 19:49:41     /api/v1//api/v1/items?page=2     HTTP/1.1         200
# 2019-04-16 19:49:43                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 19:49:51            /api/v1//api/v1/items     HTTP/1.1         200
# 2019-04-16 19:49:53                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 19:49:58  /api/v1//api/v1/items/next_page     HTTP/1.1         200
# 2019-04-16 19:49:58                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 19:59:46              /api/v1/helloclass!     HTTP/1.1         200
# 2019-04-16 19:59:47                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 20:01:02        /api/v1/I_DIDNT_DO_IT!!!!     HTTP/1.1         200
# 2019-04-16 20:01:03                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 20:31:09             /api/v1/sales?page=3     HTTP/1.1         200
# 2019-04-16 20:31:10                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 20:57:38             /api/v1/items&page=0     HTTP/1.1         200
# 2019-04-16 21:49:21                                /     HTTP/1.1         200
# 2019-04-16 21:49:22                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 22:01:52                    /api/v1/items     HTTP/1.1         200
# 2019-04-16 22:01:52                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 22:01:53                         /api/v1/     HTTP/1.1         200
# 2019-04-16 22:01:53                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 22:02:42                         /api/v1/     HTTP/1.1         200
# 2019-04-16 22:02:42                     /favicon.ico     HTTP/1.1         200
# 2019-04-16 23:44:34                                /     HTTP/1.1         200
# 2019-04-16 23:44:35                     /favicon.ico     HTTP/1.1         200
# 2019-04-17 01:25:07                                /     HTTP/1.1         200
# 2019-04-17 01:25:21                   /documentation     HTTP/1.1         200
# 2019-04-17 01:33:06             /api/v1/items?page=2     HTTP/1.1         200
# 2019-04-17 01:33:19             /api/v1/items?page=3     HTTP/1.1         200
# 2019-04-17 01:33:32             /api/v1/items?page=4     HTTP/1.1         200
# 2019-04-17 01:56:33                   /api/v1/stores     HTTP/1.1         200
# 2019-04-17 01:56:57                    /api/v1/sales     HTTP/1.1         200
# 2019-04-17 02:07:44                    /api/v1/sales     HTTP/1.1         200
# 2019-04-17 02:18:07                                /     HTTP/1.1         200
# 2019-04-17 02:18:07                     /favicon.ico     HTTP/1.1         200
#
#                        size  \
# timestamp
# 2019-04-16 19:38:16     162
# 2019-04-16 19:38:16     162
# 2019-04-16 19:44:04    1328
# 2019-04-16 19:44:04     162
# 2019-04-16 19:44:16    1328
# 2019-04-16 19:44:16     162
# 2019-04-16 19:44:24    1328
# 2019-04-16 19:44:24     162
# 2019-04-16 19:44:28    1328
# 2019-04-16 19:44:28     162
# 2019-04-16 19:44:38    1328
# 2019-04-16 19:44:38     162
# 2019-04-16 19:45:20      48
# 2019-04-16 19:45:20     162
# 2019-04-16 19:49:41     162
# 2019-04-16 19:49:43     162
# 2019-04-16 19:49:51     162
# 2019-04-16 19:49:53     162
# 2019-04-16 19:49:58     162
# 2019-04-16 19:49:58     162
# 2019-04-16 19:59:46     162
# 2019-04-16 19:59:47     162
# 2019-04-16 20:01:02     162
# 2019-04-16 20:01:03     162
# 2019-04-16 20:31:09  499787
# 2019-04-16 20:31:10     162
# 2019-04-16 20:57:38     162
# 2019-04-16 21:49:21      42
# 2019-04-16 21:49:22     162
# 2019-04-16 22:01:52    3561
# 2019-04-16 22:01:52     162
# 2019-04-16 22:01:53     162
# 2019-04-16 22:01:53     162
# 2019-04-16 22:02:42     162
# 2019-04-16 22:02:42     162
# 2019-04-16 23:44:34      42
# 2019-04-16 23:44:35     162
# 2019-04-17 01:25:07      42
# 2019-04-17 01:25:21     348
# 2019-04-17 01:33:06    3659
# 2019-04-17 01:33:19    1787
# 2019-04-17 01:33:32      48
# 2019-04-17 01:56:33    1328
# 2019-04-17 01:56:57  493905
# 2019-04-17 02:07:44  493905
# 2019-04-17 02:18:07      42
# 2019-04-17 02:18:07     162
#
#                                                             user_agent  \
# timestamp
# 2019-04-16 19:38:16  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:38:16  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:44:04  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:44:04  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:44:16  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:44:16  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:44:24  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:44:24  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:44:28  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:44:28  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:44:38  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:44:38  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:45:20  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:45:20  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:49:41  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:49:43  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:49:51  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:49:53  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:49:58  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:49:58  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:59:46  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:59:47  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 20:01:02  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 20:01:03  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 20:31:09  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 20:31:10  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 20:57:38                                  Python-urllib/3.7
# 2019-04-16 21:49:21  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3...
# 2019-04-16 21:49:22  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3...
# 2019-04-16 22:01:52  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 22:01:52  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 22:01:53  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 22:01:53  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 22:02:42  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 22:02:42  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 23:44:34  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 23:44:35  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-17 01:25:07  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 2019-04-17 01:25:21  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 2019-04-17 01:33:06  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 2019-04-17 01:33:19  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 2019-04-17 01:33:32  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 2019-04-17 01:56:33  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 2019-04-17 01:56:57  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 2019-04-17 02:07:44  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 2019-04-17 02:18:07  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3...
# 2019-04-17 02:18:07  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3...
#
#                       size_mb  proba_path_given_ip  proba_agent_given_ip
# timestamp
# 2019-04-16 19:38:16  0.000154             0.000083              0.002167
# 2019-04-16 19:38:16  0.000154             0.001167              0.002167
# 2019-04-16 19:44:04  0.001266             0.000167              0.002167
# 2019-04-16 19:44:04  0.000154             0.001167              0.002167
# 2019-04-16 19:44:16  0.001266             0.004001              0.002167
# 2019-04-16 19:44:16  0.000154             0.001167              0.002167
# 2019-04-16 19:44:24  0.001266             0.004001              0.002167
# 2019-04-16 19:44:24  0.000154             0.001167              0.002167
# 2019-04-16 19:44:28  0.001266             0.000083              0.002167
# 2019-04-16 19:44:28  0.000154             0.001167              0.002167
# 2019-04-16 19:44:38  0.001266             0.000083              0.002167
# 2019-04-16 19:44:38  0.000154             0.001167              0.002167
# 2019-04-16 19:45:20  0.000046             0.000083              0.002167
# 2019-04-16 19:45:20  0.000154             0.001167              0.002167
# 2019-04-16 19:49:41  0.000154             0.000833              0.002167
# 2019-04-16 19:49:43  0.000154             0.001167              0.002167
# 2019-04-16 19:49:51  0.000154             0.000083              0.002167
# 2019-04-16 19:49:53  0.000154             0.001167              0.002167
# 2019-04-16 19:49:58  0.000154             0.000083              0.002167
# 2019-04-16 19:49:58  0.000154             0.001167              0.002167
# 2019-04-16 19:59:46  0.000154             0.000083              0.002167
# 2019-04-16 19:59:47  0.000154             0.001167              0.002167
# 2019-04-16 20:01:02  0.000154             0.000083              0.002167
# 2019-04-16 20:01:03  0.000154             0.001167              0.002167
# 2019-04-16 20:31:09  0.476634             0.006751              0.002167
# 2019-04-16 20:31:10  0.000154             0.001167              0.002167
# 2019-04-16 20:57:38  0.000154             0.000083              0.000083
# 2019-04-16 21:49:21  0.000040             0.007918              0.000167
# 2019-04-16 21:49:22  0.000154             0.001167              0.000167
# 2019-04-16 22:01:52  0.003396             0.048780              0.032520
# 2019-04-16 22:01:52  0.000154             0.016260              0.032520
# 2019-04-16 22:01:53  0.000154             0.008130              0.032520
# 2019-04-16 22:01:53  0.000154             0.016260              0.032520
# 2019-04-16 22:02:42  0.000154             0.008130              0.032520
# 2019-04-16 22:02:42  0.000154             0.016260              0.032520
# 2019-04-16 23:44:34  0.000040             0.012195              0.032520
# 2019-04-16 23:44:35  0.000154             0.016260              0.032520
# 2019-04-17 01:25:07  0.000040             0.012195              0.032520
# 2019-04-17 01:25:21  0.000332             0.012195              0.032520
# 2019-04-17 01:33:06  0.003489             0.044715              0.032520
# 2019-04-17 01:33:19  0.001704             0.044715              0.032520
# 2019-04-17 01:33:32  0.000046             0.004065              0.032520
# 2019-04-17 01:56:33  0.001266             0.016260              0.032520
# 2019-04-17 01:56:57  0.471025             0.012195              0.032520
# 2019-04-17 02:07:44  0.471025             0.012195              0.032520
# 2019-04-17 02:18:07  0.000040             0.001631              0.003263
# 2019-04-17 02:18:07  0.000154             0.001631              0.003263
